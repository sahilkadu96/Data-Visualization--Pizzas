# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from datetime import datetime

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Dataset downloaded from:** https://www.kaggle.com/datasets/shilongzhuang/pizza-sales

# %%
df = pd.read_csv('data/pizza_sales.csv', parse_dates = ['order_date'])
df
# Out:
#        pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 0             1         1     hawaiian_m         1 2015-01-01   11:38:36
# 1             2         2  classic_dlx_m         1 2015-01-01   11:57:40
# 2             3         2  five_cheese_l         1 2015-01-01   11:57:40
# 3             4         2    ital_supr_l         1 2015-01-01   11:57:40
# 4             5         2     mexicana_m         1 2015-01-01   11:57:40
# ...         ...       ...            ...       ...        ...        ...
# 48615     48616     21348  ckn_alfredo_m         1 2015-12-31   21:23:10
# 48616     48617     21348  four_cheese_l         1 2015-12-31   21:23:10
# 48617     48618     21348   napolitana_s         1 2015-12-31   21:23:10
# 48618     48619     21349     mexicana_l         1 2015-12-31   22:09:54
# 48619     48620     21350      bbq_ckn_s         1 2015-12-31   23:02:05
#
#        unit_price  total_price pizza_size pizza_category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_name_id      48620 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  datetime64[ns]
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48620 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48620 non-null  object
#  10  pizza_ingredients  48620 non-null  object
#  11  pizza_name         48620 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(6)
# memory usage: 4.5+ MB

# %%
df.isnull().sum()
# Out:
# pizza_id             0
# order_id             0
# pizza_name_id        0
# quantity             0
# order_date           0
# order_time           0
# unit_price           0
# total_price          0
# pizza_size           0
# pizza_category       0
# pizza_ingredients    0
# pizza_name           0
# dtype: int64

# %%
df['Month'] = df['order_date'].dt.month
df['Weekday'] = df['order_date'].dt.weekday.map({0:'Mon', 1:'Tue', 2:'Wed', 3:'Thurs', 4:'Fri', 5:'Sat', 6:'Sun'})
df['Hour'] = df['order_time'].apply(lambda x: int(x.split(':')[0]))
df
# Out:
#        pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 0             1         1     hawaiian_m         1 2015-01-01   11:38:36
# 1             2         2  classic_dlx_m         1 2015-01-01   11:57:40
# 2             3         2  five_cheese_l         1 2015-01-01   11:57:40
# 3             4         2    ital_supr_l         1 2015-01-01   11:57:40
# 4             5         2     mexicana_m         1 2015-01-01   11:57:40
# ...         ...       ...            ...       ...        ...        ...
# 48615     48616     21348  ckn_alfredo_m         1 2015-12-31   21:23:10
# 48616     48617     21348  four_cheese_l         1 2015-12-31   21:23:10
# 48617     48618     21348   napolitana_s         1 2015-12-31   21:23:10
# 48618     48619     21349     mexicana_l         1 2015-12-31   22:09:54
# 48619     48620     21350      bbq_ckn_s         1 2015-12-31   23:02:05
#
#        unit_price  total_price pizza_size pizza_category  \
# ...

# %%
df.to_csv('data/pizaa_sales_preprocessed.csv', index = False)

# %%
ingr_list = []
cat_list = []

for i in range(0, len(df)):
    ing = df['pizza_ingredients'][i].split(',')
    cat = df['pizza_category'][i]
    
    for j in ing:
        ingr_list.append(j.strip(' '))
    
    

ingr_list = pd.DataFrame({'ingredients': ingr_list})
ingr_list
# Out:
#               ingredients
# 0              Sliced Ham
# 1               Pineapple
# 2       Mozzarella Cheese
# 3               Pepperoni
# 4               Mushrooms
# ...                   ...
# 267571        Red Peppers
# 267572      Green Peppers
# 267573           Tomatoes
# 267574         Red Onions
# 267575     Barbecue Sauce
#
# [267576 rows x 1 columns]

# %%
ingr_list.to_csv('data/ingredients.csv', index = False)

# %% [markdown]
# # I have done all the analysis on Tableau!
